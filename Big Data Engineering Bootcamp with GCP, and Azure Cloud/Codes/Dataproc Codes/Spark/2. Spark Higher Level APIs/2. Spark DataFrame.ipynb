# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
.appName("DataFrame") \
.getOrCreate()

# %%
data = [(0, "Customer_0", "Bangalore", "India"),
(1, "Customer_1", "Delhi", "India")]
