# %%
from pyspark.sql import SparkSession
# Initialize Spark Session



spark = SparkSession.builder \
.appName ("DataFrame_Cache_Demo_Big_File") \
.getOrCreate()
# Out:
# 25/02/06 10:47:29 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
customers_df = spark.read.option('header','true').csv('/tmp/customers_500mb.csv')

# %%
customers_df.rdd.getNumPartitions()
# Out:
# 5

# %%
customers_df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- registration_date: string (nullable = true)
#  |-- is_active: string (nullable = true)

# %%
customers_df.show(5)
# Out:
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|   Mumbai|  Telangana|  India|       2023-03-21|     True|
# |          1|Customer_1|  Chennai|West Bengal|  India|       2023-05-27|    False|
# |          2|Customer_2|     Pune|  Karnataka|  India|       2023-10-11|    False|
# |          3|Customer_3|Hyderabad|    Gujarat|  India|       2023-11-11|    False|
# |          4|Customer_4|   Mumbai|  Karnataka|  India|       2023-05-09|    False|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
customers_df.show(5)
# Out:
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|   Mumbai|  Telangana|  India|       2023-03-21|     True|
# |          1|Customer_1|  Chennai|West Bengal|  India|       2023-05-27|    False|
# |          2|Customer_2|     Pune|  Karnataka|  India|       2023-10-11|    False|
# |          3|Customer_3|Hyderabad|    Gujarat|  India|       2023-11-11|    False|
# |          4|Customer_4|   Mumbai|  Karnataka|  India|       2023-05-09|    False|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
customers_df.count()
# Out:
# 8767358

# %%
customers_df.cache() # This behaviour can be different in different Platforms
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
customers_df.show(5)
# Out:
# [Stage 6:>                                                          (0 + 1) / 1]
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|   Mumbai|  Telangana|  India|       2023-03-21|     True|
# |          1|Customer_1|  Chennai|West Bengal|  India|       2023-05-27|    False|
# |          2|Customer_2|     Pune|  Karnataka|  India|       2023-10-11|    False|
# |          3|Customer_3|Hyderabad|    Gujarat|  India|       2023-11-11|    False|
# |          4|Customer_4|   Mumbai|  Karnataka|  India|       2023-05-09|    False|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
customers_df.show(5)
# Out:
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|   Mumbai|  Telangana|  India|       2023-03-21|     True|
# |          1|Customer_1|  Chennai|West Bengal|  India|       2023-05-27|    False|
# |          2|Customer_2|     Pune|  Karnataka|  India|       2023-10-11|    False|
# |          3|Customer_3|Hyderabad|    Gujarat|  India|       2023-11-11|    False|
# |          4|Customer_4|   Mumbai|  Karnataka|  India|       2023-05-09|    False|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
# customers_df.tail(5)

# %%
tail_df = customers_df.orderBy('customer_id', ascending=False)

# %%
tail_df.show(5)
# Out:
# [Stage 8:===============================================>           (4 + 1) / 5]
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# |customer_id|           name|     city|      state|country|registration_date|is_active|
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# |     999999|Customer_999999|Hyderabad|  Karnataka|  India|       2023-05-30|     True|
# |     999998|Customer_999998|    Delhi|West Bengal|  India|       2023-07-21|     True|
# |     999997|Customer_999997|  Kolkata|  Karnataka|  India|       2023-04-03|     True|
# |     999996|Customer_999996|Hyderabad|Maharashtra|  India|       2023-09-03|     True|
# |     999995|Customer_999995|     Pune|    Gujarat|  India|       2023-05-03|    False|
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
tail_df.show(5)
# Out:
# [Stage 9:===============================================>           (4 + 1) / 5]
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# |customer_id|           name|     city|      state|country|registration_date|is_active|
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# |     999999|Customer_999999|Hyderabad|  Karnataka|  India|       2023-05-30|     True|
# |     999998|Customer_999998|    Delhi|West Bengal|  India|       2023-07-21|     True|
# |     999997|Customer_999997|  Kolkata|  Karnataka|  India|       2023-04-03|     True|
# |     999996|Customer_999996|Hyderabad|Maharashtra|  India|       2023-09-03|     True|
# |     999995|Customer_999995|     Pune|    Gujarat|  India|       2023-05-03|    False|
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
customers_df.tail(5)
# Out:
# [Row(customer_id='8767353', name='Customer_8767353', city='Kolkata', state='Delhi', country='India', registration_date='2023-10-22', is_active='False'),
#  Row(customer_id='8767354', name='Customer_8767354', city='Delhi', state='Maharashtra', country='India', registration_date='2023-09-07', is_active='False'),
#  Row(customer_id='8767355', name='Customer_8767355', city='Kolkata', state='Gujarat', country='India', registration_date='2023-11-02', is_active='True'),
#  Row(customer_id='8767356', name='Customer_8767356', city='Pune', state='West Bengal', country='India', registration_date='2023-04-08', is_active='True'),
#  Row(customer_id='8767357', name='Customer_8767357', city='Pune', state='Gujarat', country='India', registration_date='2023-07-12', is_active='False')]

# %%
customers_df.count()
# Out:
# 8767358

# %%
customers_df.unpersist()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
customers_df.cache()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
customers_df.tail(5)
# Out:
# [Row(customer_id='8767353', name='Customer_8767353', city='Kolkata', state='Delhi', country='India', registration_date='2023-10-22', is_active='False'),
#  Row(customer_id='8767354', name='Customer_8767354', city='Delhi', state='Maharashtra', country='India', registration_date='2023-09-07', is_active='False'),
#  Row(customer_id='8767355', name='Customer_8767355', city='Kolkata', state='Gujarat', country='India', registration_date='2023-11-02', is_active='True'),
#  Row(customer_id='8767356', name='Customer_8767356', city='Pune', state='West Bengal', country='India', registration_date='2023-04-08', is_active='True'),
#  Row(customer_id='8767357', name='Customer_8767357', city='Pune', state='Gujarat', country='India', registration_date='2023-07-12', is_active='False')]

# %%
customers_df.unpersist()
customers_df.cache()

# %%
tail_df = customers_df.orderBy('customer_id', ascending=False)
tail_df.show(5)
# Out:
# [Stage 15:==================================>                       (3 + 2) / 5]
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# |customer_id|           name|     city|      state|country|registration_date|is_active|
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# |     999999|Customer_999999|Hyderabad|  Karnataka|  India|       2023-05-30|     True|
# |     999998|Customer_999998|    Delhi|West Bengal|  India|       2023-07-21|     True|
# |     999997|Customer_999997|  Kolkata|  Karnataka|  India|       2023-04-03|     True|
# |     999996|Customer_999996|Hyderabad|Maharashtra|  India|       2023-09-03|     True|
# |     999995|Customer_999995|     Pune|    Gujarat|  India|       2023-05-03|    False|
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
tail_df.show(5)
# Out:
# [Stage 16:===========>                                              (1 + 4) / 5]
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# |customer_id|           name|     city|      state|country|registration_date|is_active|
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# |     999999|Customer_999999|Hyderabad|  Karnataka|  India|       2023-05-30|     True|
# |     999998|Customer_999998|    Delhi|West Bengal|  India|       2023-07-21|     True|
# |     999997|Customer_999997|  Kolkata|  Karnataka|  India|       2023-04-03|     True|
# |     999996|Customer_999996|Hyderabad|Maharashtra|  India|       2023-09-03|     True|
# |     999995|Customer_999995|     Pune|    Gujarat|  India|       2023-05-03|    False|
# +-----------+---------------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
customers_df.unpersist()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
customers_df.cache()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
customer_id_filtered = customers_df.filter((customers_df.customer_id>='100000') & (customers_df.customer_id<='4000000'))

# %%
customer_id_filtered.count()
# Out:
# 3333335

# %%
filtered_df = customers_df.filter(customers_df.city=='Mumbai')
filtered_df.show(5)
# Out:
# +-----------+-----------+------+-----------+-------+-----------------+---------+
# |customer_id|       name|  city|      state|country|registration_date|is_active|
# +-----------+-----------+------+-----------+-------+-----------------+---------+
# |          9| Customer_9|Mumbai|  Telangana|  India|       2023-01-05|     True|
# |         15|Customer_15|Mumbai|    Gujarat|  India|       2023-03-02|     True|
# |         33|Customer_33|Mumbai|West Bengal|  India|       2023-09-11|    False|
# |         60|Customer_60|Mumbai| Tamil Nadu|  India|       2023-12-01|     True|
# |         63|Customer_63|Mumbai|  Karnataka|  India|       2023-05-23|     True|
# +-----------+-----------+------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
customers_df.unpersist()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
filtered_df = customers_df.filter(customers_df.city=='Mumbai')
filtered_df.show(5)
# Out:
# +-----------+-----------+------+----------+-------+-----------------+---------+
# |customer_id|       name|  city|     state|country|registration_date|is_active|
# +-----------+-----------+------+----------+-------+-----------------+---------+
# |          0| Customer_0|Mumbai| Telangana|  India|       2023-03-21|     True|
# |          4| Customer_4|Mumbai| Karnataka|  India|       2023-05-09|    False|
# |         28|Customer_28|Mumbai|   Gujarat|  India|       2023-09-03|     True|
# |         42|Customer_42|Mumbai| Karnataka|  India|       2023-01-27|    False|
# |         47|Customer_47|Mumbai|Tamil Nadu|  India|       2023-08-15|    False|
# +-----------+-----------+------+----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
customers_df.unpersist()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
agg_df = customers_df.groupBy('city').count()
agg_df.show()
# Out:
# [Stage 26:==============================================>           (4 + 1) / 5]
# +---------+-------+
# |     city|  count|
# +---------+-------+
# |Bangalore|1094195|
# |  Chennai|1095052|
# |   Mumbai|1095815|
# |Ahmedabad|1097162|
# |  Kolkata|1096777|
# |     Pune|1095748|
# |    Delhi|1096183|
# |Hyderabad|1096426|
# +---------+-------+

# %%
spark.stop()
